# %%
initial_amount = 0
monthly_investment = 1300
yearly_investment = 12 * monthly_investment
annunal_growth_rate = 0.1
years = 5

growth = 0
growth_growth = 0

for year in range(years):
    initial_amount += yearly_investment
    growth_growth += growth * annunal_growth_rate + growth_growth * annunal_growth_rate
    growth = initial_amount * annunal_growth_rate
    total_amount = initial_amount + growth + growth_growth
    print(f"Year {year + 1}: Total Amount: {total_amount:.2f}, Put in Amount: {initial_amount:.2f}, Growth: {growth:.2f}, Growth of Growth: {growth_growth:.2f}")
# Out:
# Year 1: Total Amount: 17160.00, Put in Amount: 15600.00, Growth: 1560.00, Growth of Growth: 0.00
# Year 2: Total Amount: 34476.00, Put in Amount: 31200.00, Growth: 3120.00, Growth of Growth: 156.00
# Year 3: Total Amount: 51963.60, Put in Amount: 46800.00, Growth: 4680.00, Growth of Growth: 483.60
# Year 4: Total Amount: 69639.96, Put in Amount: 62400.00, Growth: 6240.00, Growth of Growth: 999.96
# Year 5: Total Amount: 87523.96, Put in Amount: 78000.00, Growth: 7800.00, Growth of Growth: 1723.96
