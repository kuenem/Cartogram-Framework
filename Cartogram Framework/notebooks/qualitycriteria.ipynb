# %%
import os
import sys
import numpy as np

project_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(project_dir)

from src.cartograms import *
from src.utils.common import *
from src.tests import *
from src.io import *

# %%
region, level, year = get_region("taiwan")
path = os.path.join(project_dir, "data/geojson/cpp/taiwan/contiguous.geojson")

data_ext, org_data = load_external_cartogram(path, region, level, year)
quality = quality_criteria(data_ext, org_data=org_data)
for k, v in quality.items():
    print(f"{k}: {v}")
# Out:
# Matched name column: 'Entity', value column: 'gdp'
# Number of unmatched regions for year 2024: 0
# Mean cartographic error: 0.03367966765647273
# Max cartographic error: 0.4418770237141073
# Mean success rate SR(N): 0.9731282712605872
# Topological accuracy: 0.0
# Mean Hamming distance: 0.3811721164577603
# Max Hamming distance: 0.9069219002272022
# Mean angular orientation error: 0.1970571576797062
# Orthogonal direction error: 0.10873440285204991
# Invalid (self-intersecting) polygon count: 0
# Overlap area fraction: 0.0
# Gap area fraction: 3.986865302576532
# Mean vertex count: 271.02941176470586

# %%
print(sum(r["original_area"] for r in data_ext.values()))
print(sum(r["new_area"] for r in data_ext.values()))
# Out:
# 947.1073117950582
# 947.1073117950583
