# %%
import os
import sys
import numpy as np

project_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(project_dir)

from src.viz import *

# %%
saved = save_all()
print(f"Saved {len(saved)} files:")
for p in saved:
    print(" -", p)
# Out:
# Saved 36 files:
#  - qc_figures/Cartographic.png
#  - qc_figures/Cartographic.svg
#  - qc_figures/Cartographic.pdf
#  - qc_figures/ShapeDeformation.png
#  - qc_figures/ShapeDeformation.svg
#  - qc_figures/ShapeDeformation.pdf
#  - qc_figures/HammingDistance.png
#  - qc_figures/HammingDistance.svg
#  - qc_figures/HammingDistance.pdf
#  - qc_figures/PositionalFidelity.png
#  - qc_figures/PositionalFidelity.svg
#  - qc_figures/PositionalFidelity.pdf
#  - qc_figures/AdjacencyError.png
#  - qc_figures/AdjacencyError.svg
#  - qc_figures/AdjacencyError.pdf
#  - qc_figures/Overlap.png
#  - qc_figures/Overlap.svg
#  - qc_figures/Overlap.pdf
#  - qc_figures/GapError.png
#  - qc_figures/GapError.svg
#  - qc_figures/GapError.pdf
#  - qc_figures/SpatialDeformation.png
#  - qc_figures/SpatialDeformation.svg
#  - qc_figures/SpatialDeformation.pdf
#  - qc_figures/GlobalShapePreservation.png
#  - qc_figures/GlobalShapePreservation.svg
#  - qc_figures/GlobalShapePreservation.pdf
#  - qc_figures/LocalShape.png
#  - qc_figures/LocalShape.svg
#  - qc_figures/LocalShape.pdf
#  - qc_figures/Complexity.png
#  - qc_figures/Complexity.svg
#  - qc_figures/Complexity.pdf
#  - qc_figures/DataInkRatio.png
#  - qc_figures/DataInkRatio.svg
#  - qc_figures/DataInkRatio.pdf
