# %%
from gastner_to_entity_format import convert_gastner_csv, merge_gastner_csvs

# %%
input = csv = "/home/kuenem/Documents/development/lectures/Master Thesis/cartogram-cpp/sample_data/usa_by_state_since_1959/usa_electors_2016.csv"

# %%
convert_gastner_csv(input, "states.csv", year="2016",
                         value_column_name="electoral_college")
# Out:
# PosixPath('states.csv')
