# %%
from gastner_to_entity_format import convert_gastner_csv, merge_gastner_csvs

# %%
input = csv = "/home/kuenem/Documents/development/lectures/Master Thesis/cartogram-cpp/sample_data/china_by_province_with_chinese_taipei_since_1998/china_taiwan_gdp_2024.csv"

# %%
convert_gastner_csv(input, "states.csv", year="2024",
                         value_column_name="gdp")
# Out:
# PosixPath('states.csv')
